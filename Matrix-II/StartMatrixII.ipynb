# %%
cd "drive/My Drive/Colab Notebooks/DataWorkshop-Matrix/"
# Out:
# /content/drive/My Drive/Colab Notebooks/DataWorkshop-Matrix

# %%
# !mkdir Matrix-II

# %%
# !mkdir Data2

# %%
# !echo -e "*\n!.gitignore" > Data2/.gitignore

# %%
# !git add Data2/.gitignore
# !git add Matrix-II

# %%
# !git config --global user.email "jetib@wp.pl"
# !git config --global user.name "RafalK"

# %%
# !git commit -m "add folders Data2 and Matrix-II"
# Out:
# [master 3daa08f] add folders Data2 and Matrix-II
#  1 file changed, 2 insertions(+)
#  create mode 100644 Data2/.gitignore

# %%
# !git push -u origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (4/4), 337 bytes | 168.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Rafal-KOSINSKR/DataWorkshop-Matrix.git
#    edca011..3daa08f  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# !git add Matrix-II
